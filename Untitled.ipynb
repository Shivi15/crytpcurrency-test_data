# %%
import matplotlib.pyplot as plt
import plotly
plotly.offline.init_notebook_mode(connected=True)
import plotly.offline as py
import plotly.graph_objs as go


from datetime import datetime
import datetime as dt
import pandas as pd
from pandas_datareader.fred import FredReader


pd.core.common.is_list_like = pd.api.types.is_list_like

import pandas_datareader.data as web
# from pandas.api.types import is_list_like


import csv


from pandas.tools.plotting import scatter_matrix

, 
import statistics

import seaborn as sns
# %matplotlib inline
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df = pd.read_csv('C:\\Users\\ShiviMalhotra\\Desktop\\research material\\crypto-markets.csv') 
df1 = pd.read_csv('C:\\Users\\ShiviMalhotra\\Desktop\\research material\\bitcoins.csv')

# %%
df['difference'] = (df['high'] - df['low']) 

df.head()
# Out:
#       slug symbol     name       date  ranknow    open    high     low  \
# 0  bitcoin    BTC  Bitcoin  4/28/2013        1  135.30  135.98  132.10
# 1  bitcoin    BTC  Bitcoin  4/29/2013        1  134.44  147.49  134.00
# 2  bitcoin    BTC  Bitcoin  4/30/2013        1  144.00  146.93  134.05
# 3  bitcoin    BTC  Bitcoin   5/1/2013        1  139.00  139.89  107.72
# 4  bitcoin    BTC  Bitcoin   5/2/2013        1  116.38  125.60   92.28
#
#     close  volume        market  close_ratio  spread  difference
# 0  134.21     0.0  1.500520e+09       0.5438    3.88        3.88
# 1  144.54     0.0  1.491160e+09       0.7813   13.49       13.49
# 2  139.00     0.0  1.597780e+09       0.3843   12.88       12.88
# 3  116.99     0.0  1.542820e+09       0.2882   32.17       32.17
# 4  105.21     0.0  1.292190e+09       0.3881   33.32       33.32

# %%
df['mean_of_diff']= df['difference'].mean()
df.head()
# Out:
#       slug symbol     name       date  ranknow    open    high     low  \
# 0  bitcoin    BTC  Bitcoin  4/28/2013        1  135.30  135.98  132.10
# 1  bitcoin    BTC  Bitcoin  4/29/2013        1  134.44  147.49  134.00
# 2  bitcoin    BTC  Bitcoin  4/30/2013        1  144.00  146.93  134.05
# 3  bitcoin    BTC  Bitcoin   5/1/2013        1  139.00  139.89  107.72
# 4  bitcoin    BTC  Bitcoin   5/2/2013        1  116.38  125.60   92.28
#
#     close  volume        market  close_ratio  spread  difference  mean_of_diff
# 0  134.21     0.0  1.500520e+09       0.5438    3.88        3.88    139.376372
# 1  144.54     0.0  1.491160e+09       0.7813   13.49       13.49    139.376372
# 2  139.00     0.0  1.597780e+09       0.3843   12.88       12.88    139.376372
# 3  116.99     0.0  1.542820e+09       0.2882   32.17       32.17    139.376372
# 4  105.21     0.0  1.292190e+09       0.3881   33.32       33.32    139.376372

# %%
df['median_of_diff']= df['difference'].median()
df.head()
# Out:
#       slug symbol     name       date  ranknow    open    high     low  \
# 0  bitcoin    BTC  Bitcoin  4/28/2013        1  135.30  135.98  132.10
# 1  bitcoin    BTC  Bitcoin  4/29/2013        1  134.44  147.49  134.00
# 2  bitcoin    BTC  Bitcoin  4/30/2013        1  144.00  146.93  134.05
# 3  bitcoin    BTC  Bitcoin   5/1/2013        1  139.00  139.89  107.72
# 4  bitcoin    BTC  Bitcoin   5/2/2013        1  116.38  125.60   92.28
#
#     close  volume        market  close_ratio  spread  difference  \
# 0  134.21     0.0  1.500520e+09       0.5438    3.88        3.88
# 1  144.54     0.0  1.491160e+09       0.7813   13.49       13.49
# 2  139.00     0.0  1.597780e+09       0.3843   12.88       12.88
# 3  116.99     0.0  1.542820e+09       0.2882   32.17       32.17
# 4  105.21     0.0  1.292190e+09       0.3881   33.32       33.32
#
#    mean_of_diff  median_of_diff
# 0    139.376372          16.045
# 1    139.376372          16.045
# 2    139.376372          16.045
# ...

# %%
grouped = df.groupby('name', as_index=False)
#print(grouped.mean())
print(df.groupby('name').apply(lambda x:x.loc[x.difference == x.difference.max(), ['date', 'difference']]))
print(df.groupby('name').apply(lambda x:x.loc[x.difference == x.difference.min(), ['date', 'difference']]))   

for name,group in grouped:
      data = [go.Scatter(x=df.date, y=df.spread)]
      py.iplot(data)
      break
# Out:
#                     date  difference
# name
# Bitcoin 1699  12/22/2017      4110.4
#                  date  difference
# name
# Bitcoin 101  8/7/2013         0.0
# ...

# %%
corr_matrix = df.corr()

# %%
corr_matrix["difference"].sort_values(ascending=False)
# Out:
# difference        1.000000e+00
# spread            1.000000e+00
# volume            9.002381e-01
# high              8.467860e-01
# open              8.370501e-01
# market            8.349362e-01
# close             8.332521e-01
# low               8.121537e-01
# close_ratio       1.207104e-02
# mean_of_diff      1.620533e-16
# median_of_diff   -3.619291e-16
# ranknow                    NaN
# Name: difference, dtype: float64

# %%
attributes = ['high','low','date','difference']
scatter_matrix(df[attributes], figsize=(12,8))
# Out:
# C:\Users\ShiviMalhotra\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
#
# 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B8B899470>,
# ...
#       dtype=object)

# %%
df.plot(kind='scatter', x='high', y='low', alpha=0.1)

# %%
df.plot(kind='scatter', x='high', y='difference', alpha=0.1)

# %%
median=df["difference"].median()
df["difference"].fillna(median, inplace=True)

# %%
sns.pairplot(df)

# %%
#fig=plt.figure(1)
#ax1= fig.add_subplot(111)
#ax1.set_xlabel(df1["high"])

#ax1.set_ylabel(df1["spread"])
y = np.random.rand(10,4)
y[:,0]= np.arange(10)
#ax1.set_title("Spread with high")
start = dt.datetime(2013, 4, 28)
end = dt.datetime(2013, 12, 31)
df1.plot(x="date", y=["close_ratio", "high", "low"], kind='scatter')
                    
#f1.plot(x="date", y=["difference","high","low"], kind="bar")
#sample_data=web.DataReader(df1, 'fred', start, end)
#ax1.plot("high", "spread", data=sample_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-366a8c4ecf8d> in <module>()
#       4
#       5 #ax1.set_ylabel(df1["spread"])
# ----> 6 y = np.random.rand(10,4)
#       7 y[:,0]= np.arange(10)
#       8 #ax1.set_title("Spread with high")
#
# NameError: name 'np' is not defined

# %%
plt.scatter(df["high"],df["close_ratio"])
plt.plot(df["high"],df["close_ratio"])
plt.show()

# %%
goog = web.DataReader(df1, start='2013', end='2014',
                       data_source='fred')
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-27-1de860b178e6> in <module>()
#       1 goog = web.DataReader(df1, start='2013', end='2014',
# ----> 2                        data_source='fred')
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     352         return FredReader(symbols=name, start=start, end=end,
#     353                           retry_count=retry_count, pause=pause,
# --> 354                           session=session).read()
#     355
#     356     elif data_source == "famafrench":
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\fred.py in read(self)
#      25         """
#      26         try:
# ---> 27             return self._read()
#      28         finally:
#      29             self.close()
#
# ...
